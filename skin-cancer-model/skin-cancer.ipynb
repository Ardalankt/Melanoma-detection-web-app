# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

dataset_dir = "melanoma_cancer_dataset"
train_dir = os.path.join(dataset_dir, "train")
test_dir = os.path.join(dataset_dir, "test")

# %%
img_size = 224
batch_size = 32
validation_split = 0.1
epochs_finetune = 15
epochs_initial = 15
seed = 42

dataset_dir = "melanoma_cancer_dataset"
train_dir = os.path.join(dataset_dir, "train")
test_dir = os.path.join(dataset_dir, "test")


train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=validation_split,
    subset="training",
    seed=seed,
    image_size=(img_size, img_size),
    batch_size=batch_size,
    label_mode="binary"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=validation_split,
    subset="validation",
    seed=seed,
    image_size=(img_size, img_size),
    batch_size=batch_size,
    label_mode="binary"
)


AUTOTUNE = tf.data.AUTOTUNE

train_ds = (
    train_ds
    .map(lambda x, y: (preprocess_input(x), y))
    .cache()
    .shuffle(1000)
    .prefetch(buffer_size=AUTOTUNE)
)

val_ds = (
    val_ds
    .map(lambda x, y: (preprocess_input(x), y))
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)


labels = [int(y.numpy()) for _, y in train_ds.unbatch()]
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(labels),
    y=labels
)
class_weight_dict = dict(enumerate(class_weights))
print("Class Weights:", class_weight_dict)


test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(img_size, img_size),
    batch_size=batch_size,
    label_mode="binary",
    shuffle=False
)

test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y)).prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 9605 files belonging to 2 classes.
# Using 8645 files for training.
# Found 9605 files belonging to 2 classes.
# Using 960 files for validation.
# /var/folders/l5/7wz4c_fn2wg4t__87s7y1_rr0000gn/T/ipykernel_20679/2455520452.py:53: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   labels = [int(y.numpy()) for _, y in train_ds.unbatch()]
# Class Weights: {0: np.float64(0.9565169285240097), 1: np.float64(1.0476248182258847)}
# Found 1000 files belonging to 2 classes.
# 2025-05-27 00:22:25.144703: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
output = Dense(1, activation="sigmoid")(x)
model = Model(inputs=base_model.input, outputs=output)

# %%
print("Training with frozen EfficientNetB0")
base_model.trainable = False
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    os.path.join(dataset_dir, "model_frozen_best.keras"),
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)


model.fit(
    train_ds,
    epochs=epochs_initial,
    validation_data=val_ds,
    callbacks=[early_stop, checkpoint],
    class_weight=class_weight_dict
)

model.save(os.path.join(dataset_dir, "model_frozen.keras"))
# Out:
# Training with frozen EfficientNetB0...
# Epoch 1/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.6489 - loss: 0.6335
# Epoch 1: val_accuracy improved from -inf to 0.86979, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 220s 792ms/step - accuracy: 0.6492 - loss: 0.6333 - val_accuracy: 0.8698 - val_loss: 0.4146
# Epoch 2/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.8193 - loss: 0.4419
# Epoch 2: val_accuracy improved from 0.86979 to 0.88333, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 207s 766ms/step - accuracy: 0.8193 - loss: 0.4418 - val_accuracy: 0.8833 - val_loss: 0.3388
# Epoch 3/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.8529 - loss: 0.3701
# Epoch 3: val_accuracy improved from 0.88333 to 0.88542, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 224s 824ms/step - accuracy: 0.8529 - loss: 0.3701 - val_accuracy: 0.8854 - val_loss: 0.3046
# Epoch 4/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.8538 - loss: 0.3485
# Epoch 4: val_accuracy improved from 0.88542 to 0.89062, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 202s 748ms/step - accuracy: 0.8538 - loss: 0.3484 - val_accuracy: 0.8906 - val_loss: 0.2844
# Epoch 5/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - accuracy: 0.8692 - loss: 0.3229
# Epoch 5: val_accuracy improved from 0.89062 to 0.90000, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 204s 752ms/step - accuracy: 0.8692 - loss: 0.3229 - val_accuracy: 0.9000 - val_loss: 0.2708
# Epoch 6/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.8797 - loss: 0.3152
# Epoch 6: val_accuracy did not improve from 0.90000
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 200s 740ms/step - accuracy: 0.8797 - loss: 0.3151 - val_accuracy: 0.8969 - val_loss: 0.2596
# Epoch 7/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.8807 - loss: 0.2950
# Epoch 7: val_accuracy improved from 0.90000 to 0.90312, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 204s 754ms/step - accuracy: 0.8807 - loss: 0.2951 - val_accuracy: 0.9031 - val_loss: 0.2517
# Epoch 8/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.8833 - loss: 0.2944
# Epoch 8: val_accuracy improved from 0.90312 to 0.90833, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 211s 781ms/step - accuracy: 0.8832 - loss: 0.2944 - val_accuracy: 0.9083 - val_loss: 0.2450
# Epoch 9/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.8844 - loss: 0.2907
# Epoch 9: val_accuracy improved from 0.90833 to 0.90938, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 223s 823ms/step - accuracy: 0.8845 - loss: 0.2907 - val_accuracy: 0.9094 - val_loss: 0.2395
# Epoch 10/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.8881 - loss: 0.2830
# Epoch 10: val_accuracy improved from 0.90938 to 0.91146, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 227s 839ms/step - accuracy: 0.8881 - loss: 0.2830 - val_accuracy: 0.9115 - val_loss: 0.2354
# Epoch 11/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - accuracy: 0.8882 - loss: 0.2819
# Epoch 11: val_accuracy did not improve from 0.91146
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 223s 822ms/step - accuracy: 0.8882 - loss: 0.2819 - val_accuracy: 0.9115 - val_loss: 0.2304
# Epoch 12/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.8783 - loss: 0.2883
# Epoch 12: val_accuracy improved from 0.91146 to 0.91250, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 230s 849ms/step - accuracy: 0.8783 - loss: 0.2883 - val_accuracy: 0.9125 - val_loss: 0.2269
# Epoch 13/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8989 - loss: 0.2742
# Epoch 13: val_accuracy did not improve from 0.91250
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 224s 827ms/step - accuracy: 0.8989 - loss: 0.2742 - val_accuracy: 0.9125 - val_loss: 0.2240
# Epoch 14/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - accuracy: 0.8995 - loss: 0.2594
# Epoch 14: val_accuracy improved from 0.91250 to 0.91562, saving model to melanoma_cancer_dataset/model_frozen_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 221s 816ms/step - accuracy: 0.8995 - loss: 0.2595 - val_accuracy: 0.9156 - val_loss: 0.2210
# Epoch 15/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - accuracy: 0.8942 - loss: 0.2685
# Epoch 15: val_accuracy did not improve from 0.91562
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 221s 815ms/step - accuracy: 0.8942 - loss: 0.2684 - val_accuracy: 0.9135 - val_loss: 0.2182
# Restoring model weights from the end of the best epoch: 15.

# %%
print("Fine-tuning EfficientNetB0")
base_model.trainable = True 

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

checkpoint_path = os.path.join(dataset_dir, "model_finetuned_best.keras")

model.fit(
    train_ds,
    epochs=epochs_finetune,
    validation_data=val_ds,
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True, verbose=1),
        ModelCheckpoint(checkpoint_path, monitor="val_accuracy", save_best_only=True, verbose=1)
    ],
    class_weight=class_weight_dict
)

model.save(os.path.join(dataset_dir, "model_finetuned.keras"))
# Out:
# Fine-tuning EfficientNetB0...
# Epoch 1/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7548 - loss: 0.4872
# Epoch 1: val_accuracy improved from -inf to 0.91146, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 975s 4s/step - accuracy: 0.7550 - loss: 0.4869 - val_accuracy: 0.9115 - val_loss: 0.2455
# Epoch 2/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8878 - loss: 0.2896
# Epoch 2: val_accuracy improved from 0.91146 to 0.92604, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 947s 3s/step - accuracy: 0.8878 - loss: 0.2896 - val_accuracy: 0.9260 - val_loss: 0.2036
# Epoch 3/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9021 - loss: 0.2439
# Epoch 3: val_accuracy improved from 0.92604 to 0.93333, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 910s 3s/step - accuracy: 0.9021 - loss: 0.2438 - val_accuracy: 0.9333 - val_loss: 0.1843
# Epoch 4/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9132 - loss: 0.2244
# Epoch 4: val_accuracy improved from 0.93333 to 0.93437, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 898s 3s/step - accuracy: 0.9133 - loss: 0.2243 - val_accuracy: 0.9344 - val_loss: 0.1719
# Epoch 5/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9259 - loss: 0.1953
# Epoch 5: val_accuracy improved from 0.93437 to 0.93542, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 923s 3s/step - accuracy: 0.9259 - loss: 0.1953 - val_accuracy: 0.9354 - val_loss: 0.1623
# Epoch 6/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9269 - loss: 0.1935
# Epoch 6: val_accuracy improved from 0.93542 to 0.93750, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 936s 3s/step - accuracy: 0.9270 - loss: 0.1934 - val_accuracy: 0.9375 - val_loss: 0.1553
# Epoch 7/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9379 - loss: 0.1665
# Epoch 7: val_accuracy improved from 0.93750 to 0.93958, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 938s 3s/step - accuracy: 0.9379 - loss: 0.1665 - val_accuracy: 0.9396 - val_loss: 0.1494
# Epoch 8/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9414 - loss: 0.1543
# Epoch 8: val_accuracy improved from 0.93958 to 0.94167, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 925s 3s/step - accuracy: 0.9414 - loss: 0.1543 - val_accuracy: 0.9417 - val_loss: 0.1446
# Epoch 9/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9488 - loss: 0.1393
# Epoch 9: val_accuracy improved from 0.94167 to 0.94271, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 887s 3s/step - accuracy: 0.9487 - loss: 0.1393 - val_accuracy: 0.9427 - val_loss: 0.1407
# Epoch 10/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9522 - loss: 0.1294
# Epoch 10: val_accuracy improved from 0.94271 to 0.94375, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 909s 3s/step - accuracy: 0.9522 - loss: 0.1294 - val_accuracy: 0.9438 - val_loss: 0.1393
# Epoch 11/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9557 - loss: 0.1261
# Epoch 11: val_accuracy improved from 0.94375 to 0.94479, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 914s 3s/step - accuracy: 0.9557 - loss: 0.1261 - val_accuracy: 0.9448 - val_loss: 0.1361
# Epoch 12/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9585 - loss: 0.1122
# Epoch 12: val_accuracy did not improve from 0.94479
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 891s 3s/step - accuracy: 0.9585 - loss: 0.1122 - val_accuracy: 0.9438 - val_loss: 0.1341
# Epoch 13/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9638 - loss: 0.1042
# Epoch 13: val_accuracy improved from 0.94479 to 0.94583, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 879s 3s/step - accuracy: 0.9638 - loss: 0.1042 - val_accuracy: 0.9458 - val_loss: 0.1328
# Epoch 14/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9671 - loss: 0.0919
# Epoch 14: val_accuracy improved from 0.94583 to 0.94896, saving model to melanoma_cancer_dataset/model_finetuned_best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 873s 3s/step - accuracy: 0.9671 - loss: 0.0919 - val_accuracy: 0.9490 - val_loss: 0.1334
# Epoch 15/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9731 - loss: 0.0843
# Epoch 15: val_accuracy did not improve from 0.94896
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 876s 3s/step - accuracy: 0.9731 - loss: 0.0843 - val_accuracy: 0.9490 - val_loss: 0.1335
# Restoring model weights from the end of the best epoch: 13.

# %%
from tensorflow.keras.models import load_model

model_path = "melanoma_cancer_dataset/model_finetuned_best.keras"

model = load_model(model_path)

# %%
import tensorflow as tf
from tensorflow.keras.applications.efficientnet import preprocess_input

img_size = 224
batch_size = 32
test_dir = "melanoma_cancer_dataset/test"

AUTOTUNE = tf.data.AUTOTUNE

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(img_size, img_size),
    batch_size=batch_size,
    label_mode='binary',
    shuffle=False
)

test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y)).prefetch(AUTOTUNE)
# Out:
# Found 1000 files belonging to 2 classes.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

threshold = 0.5

y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)

probs = model.predict(test_ds)
preds = (probs > threshold).astype(int).flatten()

# Results
print("Confusion Matrix:")
print(confusion_matrix(y_true, preds))

print("\nClassification Report:")
print(classification_report(y_true, preds, target_names=["Benign", "Malignant"]))
# Out:
# 2025-05-27 09:03:03.911411: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 723ms/step
# Confusion Matrix:
# [[477  23]
#  [ 58 442]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.89      0.95      0.92       500
#    Malignant       0.95      0.88      0.92       500
#
#     accuracy                           0.92      1000
#    macro avg       0.92      0.92      0.92      1000
# weighted avg       0.92      0.92      0.92      1000

# %%
from sklearn.metrics import roc_auc_score

auc_score = roc_auc_score(y_true, probs)

print(f"\nAUC-ROC Score: {auc_score:.4f}")
# Out:
# AUC-ROC Score: 0.9789
